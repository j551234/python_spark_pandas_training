# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, substring
from pyspark.sql.types import IntegerType

spark = SparkSession.builder.master("local[1]") \
                    .appName('py_spark') \
                    .getOrCreate()


csvDF =spark.read.option("header",True).csv("/home/james/python_practice/archive/CAvideos.csv")

jsonDF =spark.read.option("multiLine", True).json("/home/james/python_practice/archive/CA_category_id.json").rdd.flatMap(lambda x:x["items"]).toDF()

joinDF=csvDF.join(jsonDF, csvDF['category_id'] == jsonDF['id'] )

data_df =data_df.withColumn("dislikes",  col('dislikes').cast(IntegerType()))
data_df=data_df.select(data_df["category_id"],data_df["dislikes"])
data_df =data_df.groupBy("category_id").sum("dislikes")
data_df.show(100)
# Out:
# +--------------------+-------------+
# |         category_id|sum(dislikes)|
# +--------------------+-------------+
# | wirkt er seltsam...|         null|
# | und schmiedet ei...|         null|
# |                  15|        81919|
# | macht er ihr ein...|         null|
# | что можно увидет...|         null|
# | ihn nach Costa R...|         null|
# |                  29|      4006492|
# | dining destinations|         null|
# |                  30|         2594|
# |                  22|      4544157|
# |                  28|       737165|
# | dass Peer Sigrid...|         null|
# | äußert jedoch di...|         null|
# |         курсы валют|         null|
# | dass Boris sich ...|         null|
# | triumphiert Xeni...|         null|
# |                null|         null|
# |           sieht sie|         null|
# |                  43|        98783|
# | ob sie der Herau...|         null|
# | который объявилс...|         null|
# | was sie für ihn ...|         null|
# | und die zeigt zu...|         null|
# |                  27|       234168|
# |                  17|      2153755|
# |                  26|       739287|
# | dass sie keinen ...|         null|
# | Selbstmord – 191...|         null|
# |  to kimchi and miso|         null|
# | beauftragt er Vi...|         null|
# | wird er prompt m...|         null|
# | and restaurant m...|         null|
# | что кто-то разры...|         null|
# | muss Gunter sein...|         null|
# | mit ihr zusammen...|         null|
# | um ihn einer exp...|         null|
# |                  19|        30503|
# | politics and mor...|         null|
# |                  23|      2557861|
# | dass er sie noch...|         null|
# | and restaurant m...|         null|
# | Abzocke und Betr...|         null|
# | ist sie zutiefst...|         null|
# | dass sie sich ni...|         null|
# |                  25|      2369587|
# | kauft sie Barolo...|         null|
# |                  44|            0|
# | seine   Meghan M...|         null|
# | die schmerzhafte...|         null|
# |              places|         null|
# | wurde es im St M...|         null|
# | der sich wieder ...|         null|
# | und als Arne sei...|         null|
# |    sie zu beruhigen|         null|
# |    was er getan hat|         null|
# | um Viktor endlic...|         null|
# | bis Olivia zufäl...|         null|
# |              #einen|         null|
# | wie sehr sie Chr...|         null|
# | um sich mit Susa...|         null|
# | die einen Rundfl...|         null|
# | als Gregor ihr k...|         null|
# | wirklich nochmal...|         null|
# | dass Gunter in G...|         null|
# |                  24|     22485534|
# | Wanja vorläufig ...|         null|
# | um die beste Lös...|         null|
# | ihm das zu versp...|         null|
# |                   1|      1864876|
# |              погода|         null|
# |                  20|      1984458|
# | 17 Aralık 2013 t...|         null|
# |                  10|     12985188|
# |       Стас Михайлов|         null|
# | mit dem weder Pa...|         null|
# |     celebrity style|         null|
# |            cencioni|         null|
# | ihre Approbation...|         null|
# | widersteht Sonja...|         null|
# | die sie selbst f...|         null|
# |                   2|       182704|
# | die extra aus Me...|         null|
# |          космонавты|         null|
# | die Feddersen be...|         null|
# +--------------------+-------------+
